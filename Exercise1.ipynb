# %%
import pandas as pd

# %%
data = {'BL': [5.6,5,5.8,3,7,4.6,7,5.6,5,5.8], 
        'BAS': [6,7,5.25,5.5,6.5,4.75,6,5.5,6.25,7],
        'BAW': [4,5,6,2,7,4.25,6,5,5.25,6],
        'PQ': [6,7,6,5.25,5.25,6,1,5.25,6,6.25],
        'OBE': [6,5,6,5.5,7,6,5,6,7,6.5]}
df = pd.DataFrame(data)

# %%
print(len(df),"\n")
print(df.shape,"\n")
print(df.index,"\n")
print(df.columns,"\n")
print(df.info(),"\n")
print(df.count(),"\n")
# Out:
# 10
#
# (10, 5)
#
# RangeIndex(start=0, stop=10, step=1)
#
# Index(['BL', 'BAS', 'BAW', 'PQ', 'OBE'], dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BL      10 non-null     float64
#  1   BAS     10 non-null     float64
#  2   BAW     10 non-null     float64
#  3   PQ      10 non-null     float64
#  4   OBE     10 non-null     float64
# dtypes: float64(5)
# memory usage: 528.0 bytes
# None
#
# BL     10
# BAS    10
# BAW    10
# PQ     10
# OBE    10
# dtype: int64

# %% [markdown]
# ## Exercise - 1
#
# 1. Display a scatter plot for Brand Loyalty and Brand Association.
# 2. Display a box plot for Perceived Quality.
# 3. Display a line plot for Brand Awareness.
# 4. Display a histogram for Brand Loyalty.
# 5. Compute the skewness of Perceived Quality.
# 6. Compute the kurtosis of Brand Loyalty.
# 7. Print the summary statistics for Overall Brand Equity.
# 8. Print the bottom 5 rows of data.
# 9. Print the median for Brand Loyalty.

# %%
#Question 1:
df.plot.scatter(x='BL', y='BAS')
# Out:
# <AxesSubplot:xlabel='BL', ylabel='BAS'>

# %%
#Question 2:
df.PQ.plot.box()
# Out:
# <AxesSubplot:>

# %%
#Question 3:
df.BAW.plot()
# Out:
# <AxesSubplot:>

# %%
#Question 4:
df.BL.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Question 5:
df.PQ.skew()
# Out:
# -2.5158094166167286

# %%
df.skew()
# Out:
# BL    -0.666452
# BAS   -0.039168
# BAW   -1.018175
# PQ    -2.515809
# OBE    0.000000
# dtype: float64

# %%
df.skew().round(2)
# Out:
# BL    -0.67
# BAS   -0.04
# BAW   -1.02
# PQ    -2.52
# OBE    0.00
# dtype: float64

# %%
#Question 6:
df.BL.kurtosis()
# Out:
# 1.3275030397427994

# %%
df.kurtosis().BL
# Out:
# 1.3275030397427994

# %%
df.kurt()
# Out:
# BL     1.327503
# BAS   -0.762976
# BAW    1.657009
# PQ     7.252133
# OBE   -0.738095
# dtype: float64

# %%
df.kurtosis().round(2)
# Out:
# BL     1.33
# BAS   -0.76
# BAW    1.66
# PQ     7.25
# OBE   -0.74
# dtype: float64

# %%
#Question 7:
df.describe().OBE
# Out:
# count    10.000000
# mean      6.000000
# std       0.707107
# min       5.000000
# 25%       5.625000
# 50%       6.000000
# 75%       6.375000
# max       7.000000
# Name: OBE, dtype: float64

# %%
df.OBE.describe()
# Out:
# count    10.000000
# mean      6.000000
# std       0.707107
# min       5.000000
# 25%       5.625000
# 50%       6.000000
# 75%       6.375000
# max       7.000000
# Name: OBE, dtype: float64

# %%
#Question 8:
df.tail(5)
# Out:
#     BL   BAS   BAW    PQ  OBE
# 5  4.6  4.75  4.25  6.00  6.0
# 6  7.0  6.00  6.00  1.00  5.0
# 7  5.6  5.50  5.00  5.25  6.0
# 8  5.0  6.25  5.25  6.00  7.0
# 9  5.8  7.00  6.00  6.25  6.5

# %%
#Question 9:
df.median().BL
# Out:
# 5.6

# %%
df.BL.median()
# Out:
# 5.6

# %%
df.median()
# Out:
# BL     5.600
# BAS    6.000
# BAW    5.125
# PQ     6.000
# OBE    6.000
# dtype: float64
