# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/BrandEquity_student_copy.xlsx')

# %%
#Checking the data summary of the dataset:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BL      999 non-null    float64
#  1   BAS     999 non-null    float64
#  2   BAW     999 non-null    float64
#  3   PQ      999 non-null    float64
#  4   OBE     999 non-null    float64
# dtypes: float64(5)
# memory usage: 39.1 KB

# %%
#Checking the data summary of the dataset:
print(len(df),"\n")
print(df.shape,"\n")
print(df.index,"\n")
print(df.columns,"\n")
print(df.info(),"\n")
print(df.count(),"\n")
# Out:
# 999
#
# (999, 5)
#
# RangeIndex(start=0, stop=999, step=1)
#
# Index(['BL', 'BAS', 'BAW', 'PQ', 'OBE'], dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BL      999 non-null    float64
#  1   BAS     999 non-null    float64
#  2   BAW     999 non-null    float64
#  3   PQ      999 non-null    float64
#  4   OBE     999 non-null    float64
# dtypes: float64(5)
# memory usage: 39.1 KB
# None
#
# BL     999
# BAS    999
# BAW    999
# PQ     999
# OBE    999
# dtype: int64

# %%
#Checking the top 5 rows of the dataset:
df.head()
# Out:
#     BL   BAS  BAW        PQ       OBE
# 0  5.6  6.00  4.0  6.000000  3.000000
# 1  5.0  7.00  5.0  7.000000  6.333333
# 2  5.8  5.25  6.0  6.000000  6.000000
# 3  3.0  5.50  2.0  5.333333  3.666667
# 4  7.0  6.50  7.0  5.333333  5.000000

# %%
#Checking the bottom 5 rows of the dataset:
df.tail()
# Out:
#       BL   BAS       BAW   PQ       OBE
# 994  6.2  6.25  6.000000  7.0  4.666667
# 995  4.8  4.75  4.000000  6.0  4.333333
# 996  4.8  4.75  4.000000  6.0  4.333333
# 997  4.2  4.00  4.666667  6.0  2.333333
# 998  6.6  6.50  6.666667  5.0  4.666667

# %%
#Checking the statistical summary of the dataset:
df.describe()
# Out:
#                BL         BAS         BAW          PQ         OBE
# count  999.000000  999.000000  999.000000  999.000000  999.000000
# mean     4.865265    5.062312    4.738739    5.343677    4.253921
# std      1.593041    1.584283    1.712961    1.516408    1.463704
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.800000    4.250000    4.000000    5.000000    3.333333
# 50%      5.400000    5.500000    5.000000    6.000000    4.333333
# 75%      6.000000    6.250000    6.000000    6.000000    5.333333
# max      7.000000    7.000000    7.000000    7.000000    7.000000

# %%
df.describe().transpose()
# Out:
#      count      mean       std  min       25%       50%       75%  max
# BL   999.0  4.865265  1.593041  1.0  3.800000  5.400000  6.000000  7.0
# BAS  999.0  5.062312  1.584283  1.0  4.250000  5.500000  6.250000  7.0
# BAW  999.0  4.738739  1.712961  1.0  4.000000  5.000000  6.000000  7.0
# PQ   999.0  5.343677  1.516408  1.0  5.000000  6.000000  6.000000  7.0
# OBE  999.0  4.253921  1.463704  1.0  3.333333  4.333333  5.333333  7.0

# %%
df.describe().transpose().round(2)
# Out:
#      count  mean   std  min   25%   50%   75%  max
# BL   999.0  4.87  1.59  1.0  3.80  5.40  6.00  7.0
# BAS  999.0  5.06  1.58  1.0  4.25  5.50  6.25  7.0
# BAW  999.0  4.74  1.71  1.0  4.00  5.00  6.00  7.0
# PQ   999.0  5.34  1.52  1.0  5.00  6.00  6.00  7.0
# OBE  999.0  4.25  1.46  1.0  3.33  4.33  5.33  7.0

# %%
#Checking the statistical summary of a column in the dataset:
df.describe().BL
# Out:
# count    999.000000
# mean       4.865265
# std        1.593041
# min        1.000000
# 25%        3.800000
# 50%        5.400000
# 75%        6.000000
# max        7.000000
# Name: BL, dtype: float64

# %%
df.BAS.describe().round()
# Out:
# count    999.0
# mean       5.0
# std        2.0
# min        1.0
# 25%        4.0
# 50%        6.0
# 75%        6.0
# max        7.0
# Name: BAS, dtype: float64

# %%
df.describe().OBE.round()
# Out:
# count    999.0
# mean       4.0
# std        1.0
# min        1.0
# 25%        3.0
# 50%        4.0
# 75%        5.0
# max        7.0
# Name: OBE, dtype: float64

# %%
#Checking the skewness of the dataset:
df.skew()
# Out:
# BL    -0.680116
# BAS   -0.894351
# BAW   -0.516074
# PQ    -1.215481
# OBE   -0.321605
# dtype: float64

# %%
#Checking the skewness of the dataset in 2 decimal place:
df.skew().round(2)
# Out:
# BL    -0.68
# BAS   -0.89
# BAW   -0.52
# PQ    -1.22
# OBE   -0.32
# dtype: float64

# %%
#Checking the skewness of an individual column in the dataset:
df.skew().PQ
# Out:
# -1.2154814308921469

# %%
#Checking the skewness of an individual column in the dataset to the nearest whole number:
df.skew().PQ.round()
# Out:
# -1.0

# %%
#Checking the kurtosis of the dataset:
df.kurt()
# Out:
# BL    -0.570401
# BAS   -0.102223
# BAW   -0.887712
# PQ     0.545677
# OBE   -0.821672
# dtype: float64

# %%
#Checking the kurtosis of the dataset in 2 decimal place:
df.kurtosis().round(2)
# Out:
# BL    -0.57
# BAS   -0.10
# BAW   -0.89
# PQ     0.55
# OBE   -0.82
# dtype: float64

# %%
#Checking the kurtosis of an individual column in the dataset:
df.kurtosis().BL
# Out:
# -0.5704013121232934

# %%
#Checking the kurtosis of an individual column in the dataset in 1 decimal place:
df.kurtosis().BL.round(1)
# Out:
# -0.6

# %%
df.BAS.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.BL.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.BAW.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='BAW',y='OBE')
# Out:
# <AxesSubplot:xlabel='BAW', ylabel='OBE'>

# %%
df.PQ.plot()
# Out:
# <AxesSubplot:>

# %%
df.PQ.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
series = df.sum()
series.plot.pie(figsize=(6, 6));
